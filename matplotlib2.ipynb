# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker

# %%
src_file = Path.cwd() / 'data' / 'raw' / 'EPA_fuel_economy.csv'
image_dir = Path.cwd() / 'images'

# %%
df = pd.read_csv(src_file)

# %%
avg_by_year = df.groupby(['year'], as_index=False).agg({'comb08':'mean'}).round(2)

# %%
avg_by_year

# %%
fig, ax1 = plt.subplots()
ax1.plot(avg_by_year['year'], avg_by_year['comb08']);

# %%
fig, ax1 = plt.subplots()
ax1.plot(avg_by_year['year'], avg_by_year['comb08'])
ax1.set_xticks(np.arange(2000, 2022, 2));

# %%
fig, ax1 = plt.subplots()
ax1.plot(avg_by_year['year'], avg_by_year['comb08'])
ax1.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:0.0f}'))

# %% [markdown]
# ### BarPlot

# %%
fig, ax1 = plt.subplots()
ax1.bar(avg_by_year['year'], avg_by_year['comb08'])
ax1.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:0.0f}'))

# %%
fig, ax1 = plt.subplots()
ax1.bar(avg_by_year['year'], avg_by_year['comb08'])
ax1.set_xticks(np.arange(2000,2021,2));

# %%
fig, ax1 = plt.subplots()
ax1.barh(avg_by_year['year'], avg_by_year['comb08'])
#ax1.set_xticks(np.arange(2000,2021,2));

# %% [markdown]
# ### Scatter Plot

# %%
# scatter plot requires explicit x and y
fig, ax1 = plt.subplots()
ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title='Scatter Plot');

# %%
# scatter plot requires explicit x and y
fig, ax1 = plt.subplots()
ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
#ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title='Scatter Plot');
ax1.set_xlabel('Fuel Cost $', size=14)
ax1.set_ylabel('Displacement', size=14)
ax1.xaxis.set_major_formatter('${x:,.0f}')
ax1.tick_params(axis='x', labelrotation=45, labelsize=14)

# %%
# scatter plot requires explicit x and y
fig, ax1 = plt.subplots(figsize=(9,7))
ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
#ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title='Scatter Plot');
ax1.set_xlabel('Fuel Cost $', size=14)
ax1.set_ylabel('Displacement', size=14)
ax1.xaxis.set_major_formatter('${x:,.0f}')
ax1.tick_params(axis='x', labelrotation=45, labelsize=14)
ax1.tick_params(axis='y', labelsize=14)
# draws a vertical line at 3500
ax1.axvline(3500, color='black', linestyle=':')
# annotate the line
ax1.annotate('Target of $ 3500', xy=(3500,2), size=16)
ax1.grid(True)

# %%
# scatter plot requires explicit x and y
fig, ax1 = plt.subplots(figsize=(9,7))
ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
#ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title='Scatter Plot');
ax1.set_xlabel('Fuel Cost $', size=14)
ax1.set_ylabel('Displacement', size=14)
ax1.xaxis.set_major_formatter('${x:,.0f}')
ax1.tick_params(axis='x', labelrotation=45, labelsize=14)
ax1.tick_params(axis='y', labelsize=14)
# draws a vertical line at 3500
ax1.axhline(4.5, color='black', linestyle='-')
# annotate the line
#ax1.annotate('Target of Displacement', xy=(3500,2), size=16)
ax1.grid(True)

# %% [markdown]
# ### Using Styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
# scatter plot requires explicit x and y
fig, ax1 = plt.subplots()
ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title='Scatter Plot');

# %% [markdown]
# ### Bulk Styling

# %%
styles = ['Solarize_Light2','bmh','ggplot','fivethirtyeight','seaborn','seaborn-dark' ]
for style in styles:
    with plt.style.context(style):
        fig, ax1 = plt.subplots()
        ax1.scatter(x=df['fuelCost08'], y = df['displ'], alpha=0.5, c=df['cylinders'])
        ax1.set(xlabel= 'Fuel Cost ($)', ylabel='Displacement', title=f"Style - {style}");
