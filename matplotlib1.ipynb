# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker

# %%
src_file = Path.cwd() / 'data' / 'raw' / 'EPA_fuel_economy.csv'
image_dir = Path.cwd() / 'images'

# %%
print(Path.cwd())
# Out:
# e:\Python Data Visualization 221130

# %%
image_dir.exists()
# Out:
# True

# %%
df = pd.read_csv(src_file)
df.head(10)
# Out:
#     make        model  year  cylinders            trany  displ       VClass  \
# 0  Acura          NSX  2000        6.0  Automatic 4-spd    3.0  Two Seaters
# 1  Acura          NSX  2000        6.0     Manual 6-spd    3.2  Two Seaters
# 2    BMW      M Coupe  2000        6.0     Manual 5-spd    3.2  Two Seaters
# 3    BMW     Z3 Coupe  2000        6.0  Automatic 4-spd    2.8  Two Seaters
# 4    BMW     Z3 Coupe  2000        6.0     Manual 5-spd    2.8  Two Seaters
# 5    BMW  Z3 Roadster  2000        6.0  Automatic 4-spd    2.5  Two Seaters
# 6    BMW  Z3 Roadster  2000        6.0     Manual 5-spd    2.5  Two Seaters
# 7    BMW  Z3 Roadster  2000        6.0  Automatic 4-spd    2.8  Two Seaters
# 8    BMW  Z3 Roadster  2000        6.0     Manual 5-spd    2.8  Two Seaters
# 9    BMW           Z8  2000        8.0     Manual 6-spd    4.9  Two Seaters
#
#    co2  barrels08  fuelCost08 fuelType  highway08  city08  comb08
# 0   -1  18.311667        2600  Premium         22      15      18
# ...

# %%
df.info()

# %%
#%matplotlib inline

# %%
plt.hist(df['comb08']);

# %%
# adding ; suppresses the additinal informaitn of matplotlib
plt.hist(df['comb08']);

# %%
plt.hist(df['comb08'])
plt.xlabel('Combined Fuel Economy (MPG)')
plt.ylabel('Number of Cars')
plt.title('Combined Fuel Economy (2000-2020)')
plt.show()

# %%
# Provides more interactive examples
#%matplotlib notebook # does not work in VS Code
# need to explicitly install ipympl
# %matplotlib ipympl

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Combined Fuel Economy (MPG)')
ax.set_ylabel('Number of Cars')
ax.set_title('Combined Fuel Economy (2000-2020)')
ax.hist(df['comb08']);
#fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'])
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50))
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50),cumulative=True)
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50),histtype='step', orientation='horizontal')
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50),bins=15)
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');

# %%
fig, ax = plt.subplots()
n, bins, patches = ax.hist(df['comb08'], range=(10,50))
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of Cars', title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#n
bins

# %%
# these are the actual bars shown in histogram plot
patches

# %% [markdown]
# ### Plot multiple plots using Figures and Axes

# %%
fig,ax= plt.subplots(2)
ax[0].hist(df['comb08'], range=(10,50));
ax[1].hist(df['comb08'], range=(10,100));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, (ax1,ax2) = plt.subplots(2)
ax1.hist(df['comb08'], range=(10,50))
ax2.boxplot(df['comb08'], showfliers=False); #, range=(10,100));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax1= plt.subplots()
ax1.boxplot(df['comb08'], labels=['All']);
#ax1.set(xlabel='', ylabel='', title='')
ax1.set(xlabel='Combined Fuel Economy (MPG)',
       ylabel='Number of Cars', 
       title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax1= plt.subplots()
ax1.boxplot(df['comb08'], labels=['All'], showfliers=False);
#ax1.set(xlabel='', ylabel='', title='')
ax1.set(xlabel='Combined Fuel Economy (MPG)',
       ylabel='Number of Cars', 
       title='Combined Fuel Economy (2000-2020)');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, (ax1, ax2) = plt.subplots(2)
ax1.hist(df['comb08'], range=(10,50))
ax1.set(#xlabel='Combined MPG',
       ylabel='Number of Cars', 
       title='Vehical MPG');
ax2.boxplot(df['comb08'], labels=['All'],vert=False, showfliers=False);
ax2.set(ylabel='MPG for Vehicales');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, (ax1, ax2) = plt.subplots(2)
ax1.hist(df['comb08'], range=(10,50))
ax1.set(title='Vehicle MPG', xlabel='Combined MPG', ylabel='Number of Cars')

ax2.boxplot(df['comb08'], labels=['All'], vert=False, showfliers=False)
ax2.set(ylabel='MPG for vehicles')

fig.suptitle('MPG Distribution', fontsize=14, fontweight='bold');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Controlling the Axes objects

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
ax1.hist(df['comb08'], range=(10,50))
ax1.set(title='Vehicle MPG', xlabel='Combined MPG', ylabel='Number of Cars')

ax2.boxplot(df['comb08'], labels=['All'], showfliers=False)
ax2.set(ylabel='MPG for vehicles')
fig.suptitle('MPG Distribution', fontsize=14, fontweight='bold');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig.savefig(image_dir/'mpg_dist.png', transparent=True, dpi=80,
                bbox_inches='tight')

# %%
print(image_dir)
# Out:
# e:\Python Data Visualization 221130\images
